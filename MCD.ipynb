# %% [markdown]
# <a href="https://colab.research.google.com/github/atrahay/news_nao/blob/main/MCD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import math
import pandas as pd

df = pd.DataFrame(columns=['source', 'author', 'title', 'description', 'url', 'urlToImage', 'publishedAt', 'content'])
df
API_KEY = "258275c0180041fb82b5f9d574799473"
url = f"https://newsapi.org/v2/everything?q=karate%20world%20championships&sortBy=publishedAt&apiKey={API_KEY}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    nb_pages = math.ceil(data["totalResults"] / 100) # pagination
else:
    print('Error:', response.status_code)
for counter in range(1, nb_pages + 1):
  url = f"https://newsapi.org/v2/everything?q=karate%20world%20championships&sortBy=publishedAt&page={counter}&apiKey={API_KEY}"
  response = requests.get(url)
  if response.status_code == 200:
      data = response.json()
  else:
      print('Error:', response.status_code)
  for count in range(100):
    if count < len(data["articles"]):
      my_dict = data["articles"][count]
      my_list = [my_dict['source']['name'], my_dict['author'], my_dict['title'], my_dict['description'], my_dict['url'], my_dict['urlToImage'], my_dict['publishedAt'], my_dict['content']]
      df.loc[count + (counter - 1) * 100]= my_list
      
df
# Out:
#                         source              author  \
# 0                    USA Today          Nolan King
# 1            Los Angeles Times       Eduard Cauich
# 2        Thefreedictionary.com                None
# 3                  Screen Rant  Sarah Beth Waldrop
# 4  AllAfrica - Top Africa News                None
# 5                    MMA Mania            SethGeko
# 6                Vnexpress.net           VnExpress
# 7           The Indian Express        Nitin Sharma
#
#                                                title  \
# 0  On the Doorstep: 5 fighters who could make UFC...
# 1  Mexican football star Diana Flores' Super Bowl...
# 2                                Chuck Norris (1940)
# 3  What Choo Sung-hoon's Done Since Physical 100 ...
# 4                       Rwanda's Top Female Referees
# 5                         Krylov vs. Spann Breakdown
# 6       Tỷ phú công nghệ thường chơi môn thể thao gì
# 7  World Cup bronze in women’s 10m air rifle, cou...
#
#                                          description  \
# 0  For those who make it to the highest stage, th...
# 1  The Mexican flag football quarterback is rever...
# 2  Carlos "Chuck" Norris is an American martial a...
# 3  Physical 100's Choo Sung-hoon performed well o...
# 4  [New Times] Competitive sport has been an over...
# 5  Twitter: @DadHallOfFamer \r\n\r\n\r\nWordpress...
# 6  Bill Gates là tín đồ của tennis và bóng ném, t...
# 7  Bengaluru girl started shooting during lockdow...
#
#                                                  url  \
# 0  https://mmajunkie.usatoday.com/lists/ufc-on-th...
# 1  https://www.latimes.com/sports/story/2023-03-1...
# 2  https://encyclopedia.thefreedictionary.com/Chu...
# 3  https://screenrant.com/physical-100-choo-sung-...
# 4    https://allafrica.com/stories/202303010270.html
# 5  https://www.mmamania.com/2023/2/23/23612095/kr...
# 6  https://vnexpress.net/ty-phu-cong-nghe-thuong-...
# 7  https://indianexpress.com/article/sports/sport...
#
#                                           urlToImage           publishedAt  \
# 0  https://mmajunkie.usatoday.com/wp-content/uplo...  2023-03-14T13:30:33Z
# 1  https://ca-times.brightspotcdn.com/dims4/defau...  2023-03-13T12:30:16Z
# 2            http://img.tfd.com/TFDlogo1200x1200.png  2023-03-10T05:00:00Z
# 3  https://static1.srcdn.com/wordpress/wp-content...  2023-03-01T22:20:20Z
# 4  https://cdn08.allafrica.com/static/images/stru...  2023-03-01T10:39:30Z
# 5  https://cdn.vox-cdn.com/uploads/community/sbnu...  2023-02-23T17:38:54Z
# 6  https://vcdn1-sohoa.vnecdn.net/2023/02/23/e0kz...  2023-02-23T05:00:00Z
# 7  https://images.indianexpress.com/2023/02/Tilot...  2023-02-21T17:47:19Z
#
#                                              content
# 0  Image via Fury FC\r\nRecord: 5-0Age: 25Weight ...
# 1  Her fans know that Diana Flores is a slippery,...
# 2  This article is about the American martial art...
# 3  Choo Sung-hoon became instantly popular on Net...
# 4  Competitive sport has been an overwhelmingly m...
# 5  Twitter: @DadHallOfFamer \r\n\n\n\nWordpress: ...
# 6  Bill Gates là tín ca tennis và bóng ném, trong...
# 7  In 2020 during the Covid-19 lockdown and subse...

# %%
from datetime import date, timedelta
today = date.today() # today
day = timedelta(days=1) # 1 day duration

for counter in range(30):
  temp_date = today - counter*day
  date = f"{temp_date.year}-{temp_date.month}-{temp_date.day}"
  nwe_date = f"https://newsapi.org/v2/everything?q=karate&from={date}&sortBy=publishedAt&apiKey={API_KEY}"
  print(f"https://newsapi.org/v2/everything?q=karate&from={date}&sortBy=publishedAt&apiKey={API_KEY}")

nwe_date
# Out:
# https://newsapi.org/v2/everything?q=karate&from=2023-3-22&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-21&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-20&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-19&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-18&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-17&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-16&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-15&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-14&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-13&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-12&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-11&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-10&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-9&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-8&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-7&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-6&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-5&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-4&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-3&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-2&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-3-1&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-28&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-27&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-26&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-25&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-24&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-23&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-22&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# https://newsapi.org/v2/everything?q=karate&from=2023-2-21&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473
# 'https://newsapi.org/v2/everything?q=karate&from=2023-2-21&sortBy=publishedAt&apiKey=258275c0180041fb82b5f9d574799473'

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

text = " ".join(df['content'])

wordcloud = WordCloud(width=800, height=800, background_color='white', max_words=50, stopwords=None, min_font_size=10).generate(text)
                                                                                                  
plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer

publishedAt = (df['publishedAt'])

# Create a CountVectorizer object
vectorizer = CountVectorizer()

# Fit the vectorizer to the preprocessed text data
vectorizer.fit_transform(publishedAt)

# Get the list of unique words in the text data
words = vectorizer.get_feature_names_out()

# Calculate the frequency of each word in the text data
word_freq = vectorizer.transform(publishedAt).toarray().sum(axis=0)

fig, ax = plt.subplots(figsize=(10,6))
ax.barh(words[np.argsort(word_freq)[-20:]], np.sort(word_freq)[-20:])
ax.set_xlabel('date')
ax.set_ylabel('link')
ax.invert_yaxis()
plt.show()

# %%
import matplotlib.pyplot as plt

data = [25, 40, 10, 25, 7]
labels = ['Groupe A', 'Groupe B', 'Groupe C', 'Groupe D', 'Argent']
plt.pie(data, labels=labels)
plt.show()

# %%
import matplotlib.pyplot as plt
names = ['A', 'B', 'C'] # nom des barres
values = [1, 10, 100]
plt.bar(names, values) ; plt.show() # Tracer

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lecture des données du fichier CSV dans un dataframe
df =pd.read_csv("KARATE.csv")

# Calcul du total pour chaque catégorie
totals = df.groupby('Édition')['Total'].sum()

# Création du graphique camembert à partir des totaux
plt.bar(totals, labels=totals.index)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lecture des données du fichier CSV dans un dataframe
df = pd.read_csv("KARATE.csv")

names = ['Édition'] # nom des barres
values = ['Or']
plt.bar('Édition','Or') ; plt.show() # Tracer

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lecture des données du fichier CSV dans un dataframe
df = pd.read_csv("KARATE.csv")

# Création du graphique à barres
plt.bar(df['Edition'], df['Or'])

# Affichage du graphique
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Edition'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-08b4b24357bb> in <module>
#       6
#       7 # Création du graphique à barres
# ----> 8 plt.bar(df['Edition'], df['Or'])
#       9
#      10 # Affichage du graphique
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Edition'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Lecture des données du fichier CSV dans un dataframe
df = pd.read_csv("KARATE.csv")

# Extraire les données pour les médailles d'or
gold = df['Or']

# Créer une liste de noms de pays correspondant aux données
names = list(df['Pays'])

# Créer le graphique à barres
plt.bar(names, gold)

#
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Pays'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-7a35be30afcb> in <module>
#       9
#      10 # Créer une liste de noms de pays correspondant aux données
# ---> 11 names = list(df['Pays'])
#      12
#      13 # Créer le graphique à barres
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Pays'
